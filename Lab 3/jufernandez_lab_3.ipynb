# %% [markdown]
# <a href="https://colab.research.google.com/github/JulianFernandez1620/MetNumUN2023I/blob/main/Lab%203/jufernandez_lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **CERTIFICADO 1**

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %% [markdown]
# **CERTIFICADO 2**

# %% [markdown]
# ![2.png](data:image/png;base64,...)

# %% [markdown]
# **CERTIFICADO 3**

# %% [markdown]
# ![3.png](data:image/png;base64,...)
